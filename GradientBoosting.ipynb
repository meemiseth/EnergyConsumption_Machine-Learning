# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import metrics
dataset=pd.read_csv("Downloads/energy_Consumption.csv")

#divide data into 'attributes' and 'label' sets
X = dataset.iloc[:, 1:27].values  
y=dataset.iloc[:, 27].values

#split data set into test and train
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
# Fit regression model
params = {'n_estimators': 500, 'max_depth': 20, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)

clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)

# compute test set deviance
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)

for i, y_pred in enumerate(clf.staged_predict(X_test)):
    test_score[i] = clf.loss_(y_test, y_pred)
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, clf.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')


# printing the mean absolute error, mean squared error, accuracy etc
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))  

mape = 100*(metrics.mean_absolute_error(y_test, y_pred))/y_train
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# C:\Users\Parvathi\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# MSE: 6166.8882
# Mean Absolute Error: 33.959200410160825
# Mean Squared Error: 6166.888229139234
# Root Mean Squared Error: 78.52953730373835
# Accuracy: 45.37 %.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import metrics
dataset=pd.read_csv("Downloads/energy_Consumption.csv")

#divide data into 'attributes' and 'label' sets
X = dataset.iloc[:, 1:15].values  
y=dataset.iloc[:, 27].values

#split data set into test and train
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
# Fit regression model
params = {'n_estimators': 500, 'max_depth': 20, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)

clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)

# compute test set deviance
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)

for i, y_pred in enumerate(clf.staged_predict(X_test)):
    test_score[i] = clf.loss_(y_test, y_pred)
#plot the deviation of test and train
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, clf.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')


# printing the mean absolute error, mean squared error, accuracy etc
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))  

mape = 100*(metrics.mean_absolute_error(y_test, y_pred))/y_train
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# MSE: 7661.4280
# Mean Absolute Error: 36.81614344049475
# Mean Squared Error: 7661.428024480491
# Root Mean Squared Error: 87.52958371019761
# Accuracy: 40.78 %.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import metrics
dataset=pd.read_csv("Downloads/energy_Consumption.csv")

#divide data into 'attributes' and 'label' sets
X = dataset.iloc[:, 1:10].values  
y=dataset.iloc[:, 27].values

#split data set into test and train
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
# Fit regression model
params = {'n_estimators': 500, 'max_depth': 20, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)

clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)

# compute test set deviance
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)

for i, y_pred in enumerate(clf.staged_predict(X_test)):
    test_score[i] = clf.loss_(y_test, y_pred)
#plot the deviation of test and train
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, clf.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')


# printing the mean absolute error, mean squared error, accuracy etc
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))  

mape = 100*(metrics.mean_absolute_error(y_test, y_pred))/y_train
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# MSE: 7691.2966
# Mean Absolute Error: 37.3225344814373
# Mean Squared Error: 7691.296603819198
# Root Mean Squared Error: 87.70003765004437
# Accuracy: 39.96 %.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import metrics
dataset=pd.read_csv("Downloads/energy_Consumption.csv")

#divide data into 'attributes' and 'label' sets
X = dataset.iloc[:, 1:10].values  
y=dataset.iloc[:, 28].values

#split data set into test and train
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
# Fit regression model
params = {'n_estimators': 500, 'max_depth': 20, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)

clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)

# compute test set deviance
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)

for i, y_pred in enumerate(clf.staged_predict(X_test)):
    test_score[i] = clf.loss_(y_test, y_pred)
#plot the deviation of test and train
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, clf.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')


# printing the mean absolute error, mean squared error, accuracy etc
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MSE: 30.5987
# Mean Absolute Error: 2.6407414531668603
# Mean Squared Error: 30.598728094161938
# Root Mean Squared Error: 5.531611708549502

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import metrics
dataset=pd.read_csv("Downloads/energy_Consumption.csv")

#divide data into 'attributes' and 'label' sets
X = dataset.iloc[:, 1:20].values  
y=dataset.iloc[:, 28].values

#split data set into test and train
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
# Fit regression model
params = {'n_estimators': 500, 'max_depth': 20, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)

clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)

# compute test set deviance
test_score = np.zeros((params['n_estimators'],), dtype=np.float64)

for i, y_pred in enumerate(clf.staged_predict(X_test)):
    test_score[i] = clf.loss_(y_test, y_pred)
#plot the deviation of test and train
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title('Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, clf.train_score_, 'b-',
         label='Training Set Deviance')
plt.plot(np.arange(params['n_estimators']) + 1, test_score, 'r-',
         label='Test Set Deviance')
plt.legend(loc='upper right')
plt.xlabel('Boosting Iterations')
plt.ylabel('Deviance')


# printing the mean absolute error, mean squared error, accuracy etc
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))  

mape = 100*(metrics.mean_absolute_error(y_test, y_pred))/y_train
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# MSE: 29.2271
# Mean Absolute Error: 2.539634193068856
# Mean Squared Error: 29.22714691028136
# Root Mean Squared Error: 5.406213731465059
# Accuracy: -inf %.
# C:\Users\Parvathi\Anaconda3\lib\site-packages\ipykernel_launcher.py:50: RuntimeWarning: divide by zero encountered in true_divide
